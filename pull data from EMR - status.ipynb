# %%
# !pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.2/460.2 kB 21.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.6 MB/s eta 0:00:00
# ...

# %%
import os
import sys
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# %%
# Set working directory
os.chdir("C:/Users/dair/Documents/R Scripts")

# Read .Renviron file
with open("C:/Users/dair/Documents/R Scripts/.Renviron", "r") as f:
    renviron_lines = f.readlines()
    for line in renviron_lines:
        key, value = line.strip().split("=")
        os.environ[key] = value

# Output test 1
args = sys.argv[1:]
print(f"Hello {args[0]}")

# Load libraries (Python doesn't have direct equivalents to libraries in R, so you need to install these packages separately)
# For example, you can install them using pip:
# pip install pandas selenium lxml
import pandas as pd
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# Other libraries like dplyr, lubridate, rvest, etc., don't have direct equivalents in Python, but you can achieve similar functionality using various Python libraries.
