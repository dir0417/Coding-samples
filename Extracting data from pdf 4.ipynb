# %%
pip install tabula-py pandas openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 104.0 MB/s eta 0:00:00
# ...

# %%
import tabula
import pandas as pd
from openpyxl import Workbook

# %%
pdf_path = '/content/CDPHE OEPR Supply Chain Integrity Assessment Summary Report - FINAL.pdf'
output_dir = '/content/output.xlsx'

tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)

# %%
for index, table in enumerate(tables):
    # Create a new Excel writer for each table
    excel_path = os.path.join(output_dir, f"table_{index + 1}.xlsx")
    excel_writer = pd.ExcelWriter(excel_path, engine='openpyxl')

    # Convert the data frame to Excel and save it
    table.to_excel(excel_writer, index=False, sheet_name='Sheet1')

    # Save the Excel file
    excel_writer.save()
    excel_writer.close()

print("Tables extracted and saved as Excel files.")
# Out:
# Tables extracted and saved as Excel files.
